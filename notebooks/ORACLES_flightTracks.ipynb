# %% [markdown]
# ## ORACLES (2016, 2017, 2018) Flight Tracks

# %%
import numpy as np 
import matplotlib.pyplot as plt
import xarray as xr
import cartopy
import glob

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

import act

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# ### Grab all the ORACLES Merge Files

# %%
nfiles2016 = sorted(glob.glob('/Users/jrobrien/Dissertation/data/oracles_download/*2016*.nc'))
ds_2016 = act.io.read_netcdf(nfiles2016)

# %%
ds_2016
# Out:
# <xarray.Dataset>
# Dimensions:                            (time: 6769, nephelometerwavelength: 3,
#                                         PSAPwavelength: 3, AODwavelength: 24,
#                                         SSFRwavelength: 11, PDIdiameter: 128,
#                                         TwoDSdiameter: 29, CASdiameter: 30,
#                                         CIPdiameter: 24, HVPS3diameter: 28,
#                                         SPP200diameter: 30, bound: 2,
#                                         UHSASsizebins: 92, APSsizebins: 51,
#                                         P3_module: 9, P3_position: 6)
# Coordinates:
#   * time                               (time) datetime64[ns] 2016-08-27T07:54...
#   * nephelometerwavelength             (nephelometerwavelength) float64 450.0...
#   * PSAPwavelength                     (PSAPwavelength) float64 470.0 ... 660.0
#   * AODwavelength                      (AODwavelength) float64 355.0 ... 1.65...
# ...

# %%
nfiles2017 = sorted(glob.glob('/Users/jrobrien/Dissertation/data/oracles_download/*2017*.nc'))
#ds_2017 = act.io.read_netcdf(nfiles2017, compat='override')
ds_2017 = xr.open_mfdataset(nfiles2017, combine='nested', compat='override')

# %%
nfiles2018 = sorted(glob.glob('/Users/jrobrien/Dissertation/data/oracles_download/*2018*.nc'))
ds_2018 = act.io.read_netcdf(nfiles2018)

# %% [markdown]
# ## Plot the Data

# %% [markdown]
# ### ORACLES 2016

# %%
display = act.plotting.GeographicPlotDisplay((ds_2016))

# %%
display.geoplot('time', lat_field='Latitude', lon_field='Longitude', gridlines=True)

# %% [markdown]
# ## ORACLES 2017

# %%
d17 = act.plotting.GeographicPlotDisplay((ds_2017))

# %%
d17.geoplot('time', lat_field='Latitude', lon_field='Longitude', gridlines=True)

# %% [markdown]
# ## ORACLES 2018

# %%
d18 = act.plotting.GeographicPlotDisplay(ds_2018)

# %%
d18.geoplot('time', lat_field='Latitude', lon_field='Longitude', gridlines=True)

# %% [markdown]
# ## Cartopy

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

# define the projection
fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-25, 16, -25, 20], crs=ccrs.PlateCarree())
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

# Add the ORACLES 2016 flight paths
ax.plot(
        ds_2016['Longitude'], 
        ds_2016['Latitude'],
        alpha=1,
        color='red',
        transform=ccrs.PlateCarree()
)

# Add the ORACLES 2017 flight paths
ax.plot(
        ds_2017['Longitude'],
        ds_2017['Latitude'],
        alpha=1,
        color='yellow',
        transform=ccrs.PlateCarree()
)

# Add the ORACLES 2018 flight paths
ax.plot(
        ds_2018['Longitude'],
        ds_2018['Latitude'],
        alpha=1,
        color='green',
        transform=ccrs.PlateCarree()
)

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS)

plt.show()
fig.savefig('OBRIEN_ORACLES_FlightTracks.png')
